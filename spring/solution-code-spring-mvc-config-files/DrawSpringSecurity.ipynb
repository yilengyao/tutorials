# %%
from graphviz import Digraph

# Create a new directed graph with left-to-right direction
dot = Digraph("Request", graph_attr={'labelloc': 't', 'fontsize': '20'})

with dot.subgraph(name="cluster_request") as c:
    c.attr(label="Request", style="filled,rounded", fillcolor="#ffcccc", shape="circle")

    with c.subgraph(name="cluster_header") as d:
        d.attr(label="Header", style="filled", fillcolor="#ccffcc")
        with d.subgraph(name="cluster_method") as e:
            e.attr(label="Method", style="filled", fillcolor="#ccffff")
            e.node("GET", "GET", shape="rect", style="filled", fillcolor="#c0e0c0")
        with d.subgraph(name="cluster_url") as e:
            e.attr(label="URL", style="filled", fillcolor="#ccffff")
            e.node("URL", "/accounts", shape="rect", style="filled", fillcolor="#c0e0c0")
        with d.subgraph(name="cluster_cookie") as e:
            e.attr(label="Cookie", style="filled", fillcolor="#ccffff")
            e.node("JSESSIONID", "JSESSIONID: 1234567", shape="rect", style="filled", fillcolor="#c0e0c0")
        
    # with c.subgraph(name="cluster_body") as e:
    #     e.attr(label="Body", style="filled", fillcolor="#ccffcc")
    #     e.node("Username", "Username", shape="rect", style="filled", fillcolor="#ffffcc", pos=positions['SecurityFilterChain'])
    #     e.node("Password", "Password", shape="rect", style="filled", fillcolor="pink", pos=positions['SecurityFilterChain'])

# Render the graph
dot.render("./images/usernamepasswordauthenticationflow/request", format="png", view=False)

Image("./images/usernamepasswordauthenticationflow/request.png")

# %%
from graphviz import Digraph

# Create a new directed graph with left-to-right direction
dot = Digraph("SecurityContextHolder", graph_attr={'labelloc': 't', 'fontsize': '20'})

with dot.subgraph(name="cluster_request") as c:
    c.attr(label="Security Context Holder", style="filled", fillcolor="greenyellow", shape="circle")
    c.node("", "", shape="rect", style="filled, invisible", fillcolor="greenyellow")

    # with c.subgraph(name="cluster_header") as d:
    #     d.attr(label="Header", style="filled", fillcolor="#ccffcc")
    #     with d.subgraph(name="cluster_method") as e:
    #         e.attr(label="Method", style="filled", fillcolor="#ccffff")
            # e.node("GET", "GET", shape="rect", style="filled", fillcolor="#c0e0c0")
    #     with d.subgraph(name="cluster_url") as e:
    #         e.attr(label="URL", style="filled", fillcolor="#ccffff")
    #         e.node("URL", "/contacts", shape="rect", style="filled", fillcolor="#c0e0c0")
    #     with d.subgraph(name="cluster_cookie") as e:
    #         e.attr(label="Cookie", style="filled", fillcolor="#ccffff")
    #         e.node("JSESSIONID", "JSESSIONID: 1234567", shape="rect", style="filled", fillcolor="#c0e0c0")
        
    # with c.subgraph(name="cluster_body") as e:
    #     e.attr(label="Body", style="filled", fillcolor="#ccffcc")
    #     e.node("Username", "Username", shape="rect", style="filled", fillcolor="#ffffcc", pos=positions['SecurityFilterChain'])
    #     e.node("Password", "Password", shape="rect", style="filled", fillcolor="pink", pos=positions['SecurityFilterChain'])

# Render the graph
dot.render("./images/usernamepasswordauthenticationflow/security_context_holder", format="png", view=False)

Image("./images/usernamepasswordauthenticationflow/security_context_holder.png")

# %%
from graphviz import Digraph

# Create a new directed graph with left-to-right direction
dot = Digraph("SecurityContextRepository", graph_attr={'labelloc': 't', 'fontsize': '20'})

with dot.subgraph(name="cluster_request") as c:
    c.attr(label="Security Context Repository", style="filled", fillcolor="maroon", shape="circle")
    c.node("", "", shape="rect", style="filled, invisible", fillcolor="maroon")

    # with c.subgraph(name="cluster_header") as d:
    #     d.attr(label="Header", style="filled", fillcolor="#ccffcc")
    #     with d.subgraph(name="cluster_method") as e:
    #         e.attr(label="Method", style="filled", fillcolor="#ccffff")
            # e.node("GET", "GET", shape="rect", style="filled", fillcolor="#c0e0c0")
    #     with d.subgraph(name="cluster_url") as e:
    #         e.attr(label="URL", style="filled", fillcolor="#ccffff")
    #         e.node("URL", "/contacts", shape="rect", style="filled", fillcolor="#c0e0c0")
    #     with d.subgraph(name="cluster_cookie") as e:
    #         e.attr(label="Cookie", style="filled", fillcolor="#ccffff")
    #         e.node("JSESSIONID", "JSESSIONID: 1234567", shape="rect", style="filled", fillcolor="#c0e0c0")
        
    # with c.subgraph(name="cluster_body") as e:
    #     e.attr(label="Body", style="filled", fillcolor="#ccffcc")
    #     e.node("Username", "Username", shape="rect", style="filled", fillcolor="#ffffcc", pos=positions['SecurityFilterChain'])
    #     e.node("Password", "Password", shape="rect", style="filled", fillcolor="pink", pos=positions['SecurityFilterChain'])

# Render the graph
dot.render("./images/usernamepasswordauthenticationflow/security_context_repository", format="png", view=False)

Image("./images/usernamepasswordauthenticationflow/security_context_repository.png")

# %%
from graphviz import Digraph

# Create a new directed graph with left-to-right direction
dot = Digraph("SecurityContextHolderWithSecurityContext", graph_attr={'labelloc': 't', 'fontsize': '20'})

with dot.subgraph(name="cluster_request") as c:
    c.attr(label="Security Context Holder", style="filled", fillcolor="greenyellow", shape="circle")
    with c.subgraph(name="cluster_securitycontext") as d:
        d.attr(label="Security Context", style="filled", fillcolor="lightyellow", shape="circle")
        with d.subgraph(name="cluster_authentication") as e:
            e.attr(label="Authentication", style="filled,rounded", fillcolor="fuchsia", shape="circle")
            e.node("attributes", "principal: JaneDoe\ncredential: null\nauthenticated: true\nauthorities: USER", shape="rect", style="filled", fillcolor="#ccffff")

# Render the graph
dot.render("./images/usernamepasswordauthenticationflow/authenticated_security_context_holder_with_security_context", format="png", view=False)

Image("./images/usernamepasswordauthenticationflow/authenticated_security_context_holder_with_security_context.png")

# %%
from graphviz import Digraph

# Create a new directed graph with left-to-right direction
dot = Digraph("UsernamePasswordRequest", graph_attr={'labelloc': 't', 'fontsize': '20'})

with dot.subgraph(name="cluster_request") as c:
    c.attr(label="Request", style="filled,rounded", fillcolor="#ffcccc", shape="circle")

    with c.subgraph(name="cluster_header") as d:
        d.attr(label="Header", style="filled", fillcolor="#ccffcc")
        with d.subgraph(name="cluster_method") as e:
            e.attr(label="Method", style="filled", fillcolor="#ccffff")
            e.node("GET", "POST", shape="rect", style="filled", fillcolor="#c0e0c0")
        with d.subgraph(name="cluster_url") as e:
            e.attr(label="URL", style="filled", fillcolor="#ccffff")
            e.node("URL", "/login", shape="rect", style="filled", fillcolor="#c0e0c0")

    with c.subgraph(name="cluster_body") as d:
        d.attr(label="Request Body", style="filled", fillcolor="lightyellow")
        with d.subgraph(name="cluster_username") as e:
            e.attr(label="username", style="filled", fillcolor="#ccffff")
            e.node("Username", "JaneDoe", shape="rect", style="filled", fillcolor="#c0e0c0")
        with d.subgraph(name="cluster_password") as e:
            e.attr(label="password", style="filled", fillcolor="#ccffff")
            e.node("Password", "kjladnfi*j9", shape="rect", style="filled", fillcolor="#c0e0c0")  


# Render the graph
dot.render("./images/usernamepasswordauthenticationflow/username_password_request", format="png", view=False)

Image("./images/usernamepasswordauthenticationflow/username_password_request.png")

# %%
from graphviz import Digraph

# Create a new directed graph with left-to-right direction
dot = Digraph("SecurityContext", graph_attr={'labelloc': 't', 'fontsize': '20'})

with dot.subgraph(name="cluster_securitycontext") as d:
    d.attr(label="Security Context", style="filled", fillcolor="lightyellow", shape="circle")
    with d.subgraph(name="cluster_authentication") as e:
        e.attr(label="Authentication", style="filled,rounded", fillcolor="fuchsia", shape="circle")
        e.node("attributes", "principal: JaneDoe\ncredential: null\nauthenticated: true\nauthorities: USER", shape="rect", style="filled", fillcolor="#ccffff")

# Render the graph
dot.render("./images/usernamepasswordauthenticationflow/security_context", format="png", view=False)

Image("./images/usernamepasswordauthenticationflow/security_context.png")

# %%
from graphviz import Digraph

# Create a new directed graph with left-to-right direction
dot = Digraph("BasicAuthenticationRequest", graph_attr={'labelloc': 't', 'fontsize': '20'})

with dot.subgraph(name="cluster_request") as c:
    c.attr(label="Request", style="filled,rounded", fillcolor="#ffcccc", shape="circle")

    with c.subgraph(name="cluster_header") as d:
        d.attr(label="Header", style="filled", fillcolor="#ccffcc")
        d.node("attributes", "GET /contact\n\nAuthentication\nBasic SmFuZURvZTpramxhZG5maSpqOQ==\n\nCookie\nJSESSIONID: 1234567", shape="rect", style="filled", fillcolor="#ccffff")
# Render the graph
dot.render("./images/basicauthenticationflow/request", format="png", view=False)

Image("./images/basicauthenticationflow/request.png")

# %%
# Create a new directed graph with left-to-right direction
dot = Digraph("UnauthenticatedAuthentication", graph_attr={'labelloc': 't', 'fontsize': '20'})

with dot.subgraph(name="cluster_authentication") as c:
    c.attr(label="Authentication", style="filled,rounded", fillcolor="fuchsia", shape="circle")
    c.node("attributes", "principal: JaneDoe\ncredential: kjladnfi*j9\nauthenticated: false\nauthorities: null", shape="rect", style="filled", fillcolor="#ccffff")

# Render the graph
dot.render("./images/usernamepasswordauthenticationflow/unauthenticated_authentication", format="png", view=False)

Image("./images/usernamepasswordauthenticationflow/unauthenticated_authentication.png")

# %%
# Create a new directed graph with left-to-right direction
dot = Digraph("UnauthenticatedUsernamePasswordAuthenticationToken", graph_attr={'labelloc': 't', 'fontsize': '20'})

with dot.subgraph(name="cluster_authentication") as c:
    c.attr(label="UsernamePasswordAuthenticationToken", style="filled,rounded", fillcolor="fuchsia", shape="circle")
    c.node("attributes", "principal: JaneDoe\ncredential: kjladnfi*j9\nauthenticated: false\nauthorities: null", shape="rect", style="filled", fillcolor="#ccffff")

# Render the graph
dot.render("./images/usernamepasswordauthenticationflow/unauthenticated_usernamepasswordauthenticationtoken", format="png", view=False)

Image("./images/usernamepasswordauthenticationflow/unauthenticated_usernamepasswordauthenticationtoken.png")

# %%
from graphviz import Digraph

# Create a new directed graph with left-to-right direction
dot = Digraph("UsernameEmailPasswordSignupRequest", graph_attr={'labelloc': 't', 'fontsize': '20'})

with dot.subgraph(name="cluster_request") as c:
    c.attr(label="Request", style="filled,rounded", fillcolor="#ffcccc", shape="circle")

    with c.subgraph(name="cluster_header") as d:
        d.attr(label="Header", style="filled", fillcolor="#ccffcc")
        d.node("url", "POST /signup", shape="rect", style="filled", fillcolor="#c0e0c0")

    with c.subgraph(name="cluster_body") as d:
        d.attr(label="Body", style="filled", fillcolor="lightyellow")
        d.node("body", "username: JaneDoe\nemail: JaneDoe@gmail.com\npassword: nullpointer", shape="rect", style="filled", fillcolor="#c0e0c0")


# Render the graph
dot.render("./images/usernameemailpasswordauthenticationflow/username_email_password_signup_request", format="png", view=False)

Image("./images/usernameemailpasswordauthenticationflow/username_email_password_signup_request.png")

# %%
from graphviz import Digraph

# Create a new directed graph with left-to-right direction
dot = Digraph("UsernameEmailPasswordSigninRequest", graph_attr={'labelloc': 't', 'fontsize': '20'})

with dot.subgraph(name="cluster_request") as c:
    c.attr(label="Request", style="filled,rounded", fillcolor="#ffcccc", shape="circle")

    with c.subgraph(name="cluster_header") as d:
        d.attr(label="Header", style="filled", fillcolor="#ccffcc")
        d.node("url", "POST /signin", shape="rect", style="filled", fillcolor="#c0e0c0")

    with c.subgraph(name="cluster_body") as d:
        d.attr(label="Body", style="filled", fillcolor="lightyellow")
        d.node("body", "username: JaneDoe\nemail: JaneDoe@gmail.com\npassword: nullpointer", shape="rect", style="filled", fillcolor="#c0e0c0")


# Render the graph
dot.render("./images/usernameemailpasswordauthenticationflow/username_email_password_signin_request", format="png", view=False)

Image("./images/usernameemailpasswordauthenticationflow/username_email_password_signin_request.png")

# %%
# Create a new directed graph with left-to-right direction
dot = Digraph("UnauthenticatedUsernameEmailPasswordAuthenticationToken", graph_attr={'labelloc': 't', 'fontsize': '20'})

with dot.subgraph(name="cluster_authentication") as c:
    c.attr(label="UsernameEmailPassword\nAuthenticationToken", style="filled,rounded", fillcolor="fuchsia", shape="circle")
    c.node("attributes", "principal: JaneDoe\ncredential: nullpointer\nauthenticated: false\nauthorities: null", shape="rect", style="filled", fillcolor="#ccffff")

# Render the graph
dot.render("./images/usernameemailpasswordauthenticationflow/unauthenticated_usernameemailpasswordauthenticationtoken", format="png", view=False)

Image("./images/usernameemailpasswordauthenticationflow/unauthenticated_usernameemailpasswordauthenticationtoken.png")

# %%
from graphviz import Digraph

# Create a new directed graph with left-to-right direction
dot = Digraph("SecurityContextHolderWithSecurityContext", graph_attr={'labelloc': 't', 'fontsize': '20'})

with dot.subgraph(name="cluster_request") as c:
    c.attr(label="Security Context Holder", style="filled", fillcolor="greenyellow", shape="circle")
    c.node("SecurityContext", "Security Context", shape="rect", style="filled", fillcolor="lightyellow")

    # with c.subgraph(name="cluster_header") as d:
    #     d.attr(label="Header", style="filled", fillcolor="#ccffcc")
    #     with d.subgraph(name="cluster_method") as e:
    #         e.attr(label="Method", style="filled", fillcolor="#ccffff")
            # e.node("GET", "GET", shape="rect", style="filled", fillcolor="#c0e0c0")
    #     with d.subgraph(name="cluster_url") as e:
    #         e.attr(label="URL", style="filled", fillcolor="#ccffff")
    #         e.node("URL", "/contacts", shape="rect", style="filled", fillcolor="#c0e0c0")
    #     with d.subgraph(name="cluster_cookie") as e:
    #         e.attr(label="Cookie", style="filled", fillcolor="#ccffff")
    #         e.node("JSESSIONID", "JSESSIONID: 1234567", shape="rect", style="filled", fillcolor="#c0e0c0")
        
    # with c.subgraph(name="cluster_body") as e:
    #     e.attr(label="Body", style="filled", fillcolor="#ccffcc")
    #     e.node("Username", "Username", shape="rect", style="filled", fillcolor="#ffffcc", pos=positions['SecurityFilterChain'])
    #     e.node("Password", "Password", shape="rect", style="filled", fillcolor="pink", pos=positions['SecurityFilterChain'])

# Render the graph
dot.render("./images/usernamepasswordauthenticationflow/security_context_holder_with_security_context", format="png", view=False)

Image("./images/usernamepasswordauthenticationflow/security_context_holder_with_security_context.png")
